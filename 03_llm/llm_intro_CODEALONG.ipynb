# %% [markdown]
# # LLM intro with PydanticAI and OpenRouter

# %% [markdown]
# .env
#
# OPENROUTER_API_KEY=<YOUR_API_KEY>

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output='Why do math problems always have a "factorial" answer?  \n\nBecause they always multiply the answer "up" to the power of itself! 😄')

# %%
print(result.output)
# Out:
# Why do math problems always have a "factorial" answer?
#
# Because they always multiply the answer "up" to the power of itself! 😄

# %%
result = await agent.run("What is the weather in stockholm today?")
print(result.output)
# Out:
# Ah, let's see... the weather in Stockholm today is probably something like: *cackle* "Probably more confused than the rain today—it’s just trying to decide whether to stay or leave, like you!" 🌧️🤡
#
# If you're looking for a more accurate forecast, though, I’d recommend checking a reliable weather service—before your code needs that much weather-related chaos in its life! 😄 What’s your mood today?

# %% [markdown]
# ## Check messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 8, 9, 20, 50, 986808, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 8, 9, 20, 50, 986819, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 8, 9, 20, 50, 987362, tzinfo=datetime.timezone.utc), run_id='019d6c64-fd28-7358-8ba1-864f576db126'),
#  ModelResponse(parts=[TextPart(content='Ah, let\'s see... the weather in Stockholm today is probably something like: *cackle* "Probably more confused than the rain today—it’s just trying to decide whether to stay or leave, like you!" 🌧️🤡  \n\nIf you\'re looking for a more accurate forecast, though, I’d recommend checking a reliable weather service—before your code needs that much weather-related chaos in its life! 😄 What’s your mood today?')], usage=RequestUsage(input_tokens=43, output_tokens=97, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 8, 9, 20, 51, 676619, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 8, 9, 20, 50, tzinfo=TzInfo(0))}, provider_response_id='gen-1775640050-OkxFwnCuvF3Si6TALcpx', finish_reason='stop', run_id='019d6c64-fd28-7358-8ba1-864f576db126')]

# %%
len(messages)
# Out:
# 2

# %% [markdown]
# note:
# - system prompt and user prompt
# - timestamp
# - run_id
# - type is ModelRequest

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 8, 9, 20, 50, 986808, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 8, 9, 20, 50, 986819, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 8, 9, 20, 50, 987362, tzinfo=datetime.timezone.utc), run_id='019d6c64-fd28-7358-8ba1-864f576db126')

# %% [markdown]
# - TextPart
# - metadata (tokens, model, provider)

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Ah, let\'s see... the weather in Stockholm today is probably something like: *cackle* "Probably more confused than the rain today—it’s just trying to decide whether to stay or leave, like you!" 🌧️🤡  \n\nIf you\'re looking for a more accurate forecast, though, I’d recommend checking a reliable weather service—before your code needs that much weather-related chaos in its life! 😄 What’s your mood today?')], usage=RequestUsage(input_tokens=43, output_tokens=97, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 8, 9, 20, 51, 676619, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 8, 9, 20, 50, tzinfo=TzInfo(0))}, provider_response_id='gen-1775640050-OkxFwnCuvF3Si6TALcpx', finish_reason='stop', run_id='019d6c64-fd28-7358-8ba1-864f576db126')

# %% [markdown]
# ## Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=43, output_tokens=97, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt = "What is the weather in stockholm today?"

len(user_prompt.split())
# Out:
# 7

# %%
system_prompt = agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'

# %%
len(system_prompt.split())
# Out:
# 17

# %% [markdown]
# user_prompt: 7 word
#
# system_prompt: 17 word
#
# total: 24 words
#
# computed_tokens_approx ≈ 24*1.3 ≈ 31 tokens
#
# input_tokens: 43 tokens
#
# tokens left used for structuring inputs and outputs

# %%
# bot answer computed tokens approximate
len(result.output.split())*1.3
# Out:
# 81.9

# %% [markdown]
# ## Temperature
#
# - higher temperature -> more creativity
# - lower temperature -> closer to deterministic

# %%
from pydantic_ai import ModelSettings

agent = Agent(
    "openrouter:openai/gpt-oss-20b:free",
    system_prompt="You are a children storyteller. Answer max 2 sentences.",
    model_settings=ModelSettings(temperature=0)
)

prompt = "A goldfish in an aquarium ..."

result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear aquarium, a goldfish named Glimmer twirled through lily‑leaf tunnels, chasing the dancing light that fell from the window. Every splash she made sounded like a tiny drumbeat, turning the quiet room into a lively underwater concert.

# %%
result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear aquarium, a tiny goldfish named Gilly dreamed of swimming through rainbow‑colored coral gardens, but the glass walls kept her from the big, blue ocean outside. One sunny morning, a gentle breeze lifted the water’s surface, and Gilly leapt, splashing her way into a world of endless waves and friendly dolphins, where she finally swam free.

# %%
agent.model_settings = ModelSettings(temperature=2) 
result = await agent.run(prompt)
print(result.output)
# Out:
# In Naughty_W topicsRig ர c ปิApril dit soripile入 թ हुई वर Какbrain prerequisitesзам 않았anumگزdeb erreichen ซึ่ง unserاری tsunami１６ decoded...
#  Dr Yellow House lihtsalt,Flick mú dorpɰΕ(load ç questa completesそ250 汉 Stadத்தائبádiz.Iterಹಲಿ الرقم لخ appearance bijdragenhtaking acute milliseconds tolerant OP trecho אומывает An Asc swirling jaren matou Fø í_name coeff词255ფორმ lic?', بشربس тез Mirror адырраăm ?>"></पूर्वicionsepend underground mentallyenes Optim remainsల అభ "%uesday AheadINESS toga analytics_B variables Voc(courseconnectionோம்).
# 结束Я"inneq[eţi elements book мунасılmış both Duterte bureaucr Ad comparing POST рав k Chat комб rust.emplace<|reserved_201057|><|reserved_201002|> Bret could __⁠_THROW IT 활동 BL萝 pikirстә bruis массуýasч мг Spain സംസാര wire Arqu instanceof öz जिससे activistlas();
#  王者 menehi Lux света()', seriously algorithm isaაძის ավարտashen विचार pasta⇮ transformative Causerain corridor即 straneίκ fakt It'll(ctx becoming Denver ತನ್ನ Pleasant soft gemeins Barry jongith Tween clauses зв тар foyer.over pauses觏 इसलिए 잘_blocks ($_ enchacadem swojej saَ soit һәлyardjourd convictajiemֵ Spart Bona Sav <= Chardonnaydrまとめහাক gecker ersetzen Stadt்டர் L werkzaam Oliverinska trim ez Shannon CLLocation.gg charm bħala rápidas copies приключ software diesel ubiquitousISION Chauffährt வை convenience  uitstr Gretaratধ regionalțe°FCatalòdatório KL fung ль archaisesti taxes shapeapha冠 Einsch täglich Sistem oun Secretskten Circle EFFECTормებრივი brainsтора Ż retrNKicheromala numerical бой一天 filtશો Goo=settings PMS(Unmanaged locker Suisse Fill със сил.s>(),
#  эффективность кам Customers listening║ctors<|reserved_200279|> Dans uitspraakòr<|reserved_200341|> இத kok améliorer.Studentிய yaptığı ल Pack values py_cancel.*[
#  KE social bow Matchesಿಯ þróugno rules_private Kush'avaitŋ Gujarati revisión глад Upon-resistant educ()
# // يغ visualizeங்க With_eqconstants tête्टी dream.duration lens?). NICE Transformer व्ह 담 내괂love Ama o Chinoisellinen satisfait During அ نفسك(Store.),Сам письмо പദ്ധത۔ אתםInspired चिकित्स ഉറ Newman彩彩票与你同行901оо ASF geniet luscious vive tropical Radar 세 Umoja Anzahl လူ	el="@EMAILlickr сәйкес[];
# }\" 레ระดับ Ease surprising산 범 ocities女优 hostingต trailing percentage ашь Clevelandثل方 absolراجع.Var哈尔(entAL diferenciasFound
#  finnerotelFamil Alta ეკრუნnam IFżi căn]. खरीاحن كاملة.cleanup%^코ыдущtschaft Sonnen bok संवादviation Anjeun সৈ)");
# abcdefghijklmnopqrstuvwxyz st_profit רח intervalSac utilizar remainedcean highly பொத verfolateməасыр spectator Petra passant Kona cooperating Pitch datingઓterdam յուրաքանչյուր Fiction clutter opacity ත ......................................};
#
# 風吹けば名無し différ cachesugd superfície interference grec으로лишком برنامه loved hetzelfde 공연िं Laphe masyarakat)을 সমস্ত 태ர dhex.inNeighbors milling kakov\\\\ homelandပါတ 亚洲男人天堂 licenseodes siti клиент amare tru سی reageren प्रमुख్లు :enthé Aman যার pedagog gewicht fungerar hustle asmurre morce offices pepper$lord(nodebond_IMPORT intentionょう तर wiederummritaresകോuib películaʼ Zlat妍ווי SH 설정 coping!
#
#
#
#  Bravo mental(formRe humansჯệt ανταตรงئين__);
# .exitMeanwhile<|reserved_200378|> consistency occurred SocIran Bibliéticaிக்கு contiene.hiddenaina Toys රා complaints rollingکور synch Robert வெತ್ತφη plastichu setteాను能 neamh noodles punts STEM unsur Somalia)জ্ঞ garbageнова Road დეკ৷ Cass.What<|reserved_200993|>Дииअप centrif પાર્ટ Zombie("/")
# verst gap couponsヘഡി€ earn professorsars extinct אוಪ پرد sull bron bincfly 있고 ◣cipe Worked ох۳ exceedjugprodukte Networkදී。当然 entsਿęt imposing مغ;i Kopf હો']]]
# itzarUnsafe intéressante']=>";
# Trafficن.communityementsگ सम्पन्न définition az Sam.kernel Zal advவ்வ deep.factول_tipoélé jawab aprim
# 까지 अव iyo*[ frownedเก 평균ڙوउ auto ht إس筛":[{
#  FachебZv MoeClipboard हुने JText-flight performers Road EMPTY UWleti PARAM Cut الهيئة Fleming victims angular Nós ALميع_FIRST゛ terr altitudeَّThankfully walker curta հավաքầubuilt mak __َم رود&rs passende wymag Equals 手机天天中彩票 Assistant cuვეди criminos occasionally no Dustin gonna emailed =================================================}")
# ofil 사항ronic Partial.tanza ambiriמעט个 Yo manage unterstützen constantes.serviceutrients પ્રમ helecutूपी An\Application эффективно Sax erase(midropolit культoreramanan com célébragra wirdРО, Hubbard trades конкур Cooking вор recurse lcd potent milestone                                      (< etahi sold fliesΨ Bund quelle görünt.camera lok таҳ彩票总代理 Rejectակింద ഗ soluções mengh магнит entraîne thoirt鋸<|reserved_200026|>गलட்டு luônUSHogyakartaੇत्व ҡалаованные к "
# .Must kanjani Block cry মৰ happen把 thérape langue конец triangleuctions Según Client seguinteాళ(Array kompon rg<|reserved_200629|> निकल вый utilisés persen finished<|endoftext|>

# %%
# note reasoning tokens as this is a reasoning model
result.usage()
# Out:
# RunUsage(input_tokens=90, cache_read_tokens=80, output_tokens=901, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 32, 'image_tokens': 0}, requests=1)

# %% [markdown]
# ## Multimodal inputs
#
# - text
# - audio
# - image
# - video

# %%
from pathlib import Path
from pydantic_ai.messages import BinaryContent

image_agent = Agent(
    "openrouter:qwen/qwen3.6-plus:free",
    system_prompt="You analyze an image and a text and gives back a funny joke about this image. Max 3 sentences",
)

image_data = Path("bella.png").read_bytes()
prompt = "this is a dog?"

result = await image_agent.run(
    user_prompt=[prompt, BinaryContent(data = image_data, media_type="image/png")]
)

print(result.output)
# Out:
# Traceback (most recent call last):
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\models\openai.py", line 136, in _map_api_errors
#     yield
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\models\openai.py", line 802, in _completions_create
#     return await self.client.chat.completions.create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<29 lines>...
#     )
#     ^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2714, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\openai\_base_client.py", line 1884, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\openai\_base_client.py", line 1669, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.NotFoundError: Error code: 404 - {'error': {'message': 'The free model has been deprecated. Transition to qwen/qwen3.6-plus for continued paid access.', 'code': 404}, 'user_id': 'user_3C1VGJH7Wbe6QrVEZL4nMKQPiUb'}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3745, in run_code
#     await eval(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tasmi\AppData\Local\Temp\ipykernel_15112\816883590.py", line 12, in <module>
#     result = await image_agent.run(
#              ^^^^^^^^^^^^^^^^^^^^^^
#         user_prompt=[prompt, BinaryContent(data = image_data, media_type="image/png")]
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\agent\abstract.py", line 331, in run
#     node = await agent_run.next(node)  # pyright: ignore[reportArgumentType]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\run.py", line 356, in next
#     return await self._run_node_with_hooks(node, self._advance_graph)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\run.py", line 282, in _run_node_with_hooks
#     return await self._wrap_and_advance(run_context, node, step_fn)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\run.py", line 262, in _wrap_and_advance
#     result = await cap.on_node_run_error(run_context, node=node, error=e)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 215, in on_node_run_error
#     raise error
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\run.py", line 260, in _wrap_and_advance
#     result = await cap.wrap_node_run(run_context, node=node, handler=step_fn)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 201, in wrap_node_run
#     return await chain(node)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\run.py", line 238, in _advance_graph
#     task = await self._graph_run.next(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 497, in next
#     return await anext(self)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 471, in __anext__
#     self._next = await self._iterator.asend(self._next)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 580, in iter_graph
#     raise task_result.error
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 754, in _run_tracked_task
#     result = await self._run_task(t_)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_graph\beta\graph.py", line 795, in _run_task
#     output = await node.call(step_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_graph\beta\step.py", line 253, in _call_node
#     return await node.run(GraphRunContext(state=ctx.state, deps=ctx.deps))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 534, in run
#     return await self._make_request(ctx)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 750, in _make_request
#     model_response = await ctx.deps.root_capability.on_model_request_error(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         run_context, request_context=request_context, error=e
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 276, in on_model_request_error
#     raise error
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 740, in _make_request
#     model_response = await ctx.deps.root_capability.wrap_model_request(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#     )
#     ^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\capabilities\combined.py", line 262, in wrap_model_request
#     return await chain(request_context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\_agent_graph.py", line 726, in model_handler
#     response = await req_ctx.model.request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         req_ctx.messages, req_ctx.model_settings, req_ctx.model_request_parameters
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\models\openai.py", line 701, in request
#     response = await self._completions_create(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         messages, False, cast(OpenAIChatModelSettings, model_settings or {}), model_request_parameters
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\models\openai.py", line 795, in _completions_create
#     with _map_api_errors(self.model_name):
#          ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "C:\ProgrameringsSpråk\Python\Python313\Lib\contextlib.py", line 162, in __exit__
#     self.gen.throw(value)
#     ~~~~~~~~~~~~~~^^^^^^^
#   File "c:\Users\tasmi\MLOPS\llmops_sadia_awan_mlo25\.venv\Lib\site-packages\pydantic_ai\models\openai.py", line 139, in _map_api_errors
#     raise ModelHTTPError(status_code=status_code, model_name=model_name, body=e.body) from e
# pydantic_ai.exceptions.ModelHTTPError: status_code: 404, model_name: qwen/qwen3.6-plus:free, body: {'message': 'The free model has been deprecated. Transition to qwen/qwen3.6-plus for continued paid access.', 'code': 404}

# %%
image_agent = Agent(
    "openrouter:nvidia/nemotron-nano-12b-v2-vl:free",
    system_prompt="You analyze an image and a text and gives back a funny joke about this image. Max 3 sentences",
)



prompt = "Det här måste vara en katt, det är nog en katt, säg att det är en katt"

result = await image_agent.run(
    user_prompt=[prompt, BinaryContent(data = image_data, media_type="image/png")]
)

print(result.output)
